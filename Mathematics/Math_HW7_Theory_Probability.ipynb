# %% [markdown]
# #### Задание 1
# Монетку подбрасывают 15 раз, найдите вероятность выпадения простого числа (решение на бумажке и на python).

# %% [markdown]
# У игрального кубика 6 граней, соответственно могут выпасть числа от 1 до 6. Из них 2, 3 и 5 являются простыми.
# Разделим кол-во простых чисел на общее кол-во чисел и получим вероятность.
#
# 3/6 = 0,5
#
# Вероятность выпадения простого числа 1/15. Вероятность не выпадения простого числа 1-1/15.
# Найдем вероятность выпадения простого числа хотя бы 1 раз при подбрасываниии кубика 15 раз.
# Воспользуемся формулой Бернулли.

# %%
from IPython.display import Image

# %%
Image('D:\Python3\Bernulli.jpg')

# %%
from scipy import stats
from math import factorial


def num_of_successes(n, k):
    return factorial(n)/(factorial(k) * factorial(n - k))


def probability_of_success(p, n, k):
    C_kn = num_of_successes(n, k)
    return C_kn * (p**k) * (1 - p)**(n - k)

# %%
n = 15
p = 1/15
q = 1-1/15
k = 1

# %%
probability_of_success(p, n, k)
# Out:
# 0.38064039267229743

# %% [markdown]
# #### Задание 2
# Создайте свою дискретную случайную величину с не менее, чем 10 значениями. Просемплируйте 1000 случайных значений, постройте гистограмму плотности распределения по выборке, посчитайте среднее, дисперсию и медиану.

# %%
import numpy as np
x = np.random.sample(10)
x
# Out:
# array([0.52408613, 0.72138262, 0.86067629, 0.79104865, 0.02526773,
#        0.95657211, 0.42840494, 0.88830641, 0.58480364, 0.65950632])

# %%
import random
x1 = random.choices(x, k=1000)

# %%
# x1

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x1)
# Out:
# (array([106.,   0.,   0.,   0.,  90.,  86., 202., 100., 204., 212.]),
#  array([0.02526773, 0.11839816, 0.2115286 , 0.30465904, 0.39778948,
#         0.49091992, 0.58405036, 0.6771808 , 0.77031124, 0.86344168,
#         0.95657211]),
#  <a list of 10 Patch objects>)

# %%
np.mean(x1)
# Out:
# 0.6475769067814364

# %%
np.var(x1)
# Out:
# 0.0705405122153905

# %%
np.median(x1)
# Out:
# 0.7213826151783914

# %% [markdown]
# #### Задание 3
# Задача с 17-го слайда лекции про 3 монеты. Покажите, почему 3 события являются попарно независимыми, но не являются независимыми в совокупности.

# %% [markdown]
# Два события попарно независимы, если наступление одного из них не влияет на вероятность наступления другого.
# Брошены 3 уравновешенные монеты. Если мы бросили одну монету, то вероятность выпадения орла 50%, у второй монеты вероятность выпадения орла так же составляет 50% и не зависит от первого броска.
# Докажем независимость в совокупности:
# P(A1,A2,A3) = 1/2  и не равно P(A1)* P(A2)* P(A3) = 1/2* 1/2* 1/2 = 1/8

# %% [markdown]
# #### Задание 4 (формула полной вероятности)
# В магазин привезли устройства с 3-х разных предприятий. Соотношение устройств следующее: 20% - продукция первого предприятия, 30% - продукция второго предприятия, 50% - продукция третьего предприятия; далее, 10% продукции первого предприятия высшего сорта, на втором предприятии - 5% и на третьем - 20% продукции высшего сорта. Найти вероятность того, что случайно купленная новая продукция окажется высшего сорта.

# %% [markdown]
# Решение. Обозначим через В событие, заключающееся в том, что будет куплена продукция высшего сорта, через
# A1, A2, A3 обозначим события, заключающиеся в покупке продукции, принадлежащей первому, второму и третьему предприятиям.
#
#
# P(A1) = 0.2
# P(A2) = 0.3
# P(A3) = 0.5
#
# P(B/A1) = 0.1
# P(B/A1) = 0.05
# P(B/A1) = 0.2
#
# Подставляя эти значения в формулу полной вероятности, получим искомую вероятность:
#
# P(B) = 0.2*0.1 + 0.3*0.05 + 0.5*0.2 = 0.135
